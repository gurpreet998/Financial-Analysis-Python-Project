# %%
import numpy as np 
import pandas as pd

# %%
import os 
for dirname, _, filenames in os.walk('C:\Python Projects\Financial Analysis SimpliLearn'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# C:\Python Projects\Financial Analysis SimpliLearn\Finance_data.csv
# C:\Python Projects\Financial Analysis SimpliLearn\Financial Analysis.ipynb

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')

# %%
df=pd.read_csv("C:\Python Projects\Financial Analysis SimpliLearn\Finance_data.csv")
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df=df.drop(['Mutual_Funds','Equity_Market','Debentures','Government_Bonds','Fixed_Deposits','PPF','Gold'],axis=1)

# %%
df.head(3)
# Out:
#    gender  age Investment_Avenues Stock_Marktet          Factor  \
# 0  Female   34                Yes           Yes         Returns
# 1  Female   23                Yes            No  Locking Period
# 2    Male   30                Yes           Yes         Returns
#
#               Objective          Purpose           Duration Invest_Monitor  \
# 0  Capital Appreciation  Wealth Creation          1-3 years        Monthly
# 1  Capital Appreciation  Wealth Creation  More than 5 years         Weekly
# 2  Capital Appreciation  Wealth Creation          3-5 years          Daily
#
#     Expect       Avenue What are your savings objectives?  \
# 0  20%-30%  Mutual Fund                   Retirement Plan
# 1  20%-30%  Mutual Fund                       Health Care
# 2  20%-30%       Equity                   Retirement Plan
#
#           Reason_Equity   Reason_Mutual     Reason_Bonds            Reason_FD  \
# 0  Capital Appreciation  Better Returns  Safe Investment        Fixed Returns
# ...

# %%
df=df.replace(r'^\s*$',np.nan,regex=True)

# %%
df.head()
# Out:
#    gender  age Investment_Avenues Stock_Marktet          Factor  \
# 0  Female   34                Yes           Yes         Returns
# 1  Female   23                Yes            No  Locking Period
# 2    Male   30                Yes           Yes         Returns
# 3    Male   22                Yes           Yes         Returns
# 4  Female   24                 No            No         Returns
#
#               Objective          Purpose           Duration Invest_Monitor  \
# 0  Capital Appreciation  Wealth Creation          1-3 years        Monthly
# 1  Capital Appreciation  Wealth Creation  More than 5 years         Weekly
# 2  Capital Appreciation  Wealth Creation          3-5 years          Daily
# 3                Income  Wealth Creation   Less than 1 year          Daily
# 4                Income  Wealth Creation   Less than 1 year          Daily
#
#     Expect       Avenue What are your savings objectives?  \
# 0  20%-30%  Mutual Fund                   Retirement Plan
# ...

# %%
sns.countplot(x='gender', data=df , linewidth=1,hue='gender',edgecolor='Black',legend=False)
plt.show()

# %%
sns.countplot(x='age',data=df,palette='Set3',linewidth=2,edgecolor='black',hue='age',legend=False)
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.countplot(x='gender',data=df,hue="Investment_Avenues",linewidth=2,edgecolor='Black',palette='summer')
plt.title('INVESTMENT AVENUES')

plt.subplot(1,2,2)
sns.countplot(x='gender',data=df,hue="Stock_Marktet",linewidth=2,edgecolor='Black',palette='hot')
plt.title('STOCK MARKET')
plt.show()

# %%
sns.countplot(x='Factor',data=df,edgecolor='black',palette='coolwarm',linewidth=2,hue='Factor',legend=False)
plt.title('Factor Wise Count')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x='Purpose',y='age',data=df,linestyle='--', capsize=.3,color='green')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(hue='gender',x='Duration',palette='viridis',data=df,linewidth=2,edgecolor='black')
plt.title("DURATION")

plt.subplot(1,2,2)
sns.countplot(hue='gender',x='Invest_Monitor',palette='seismic',data=df,linewidth=2,edgecolor='black')
plt.title("INVESTMENT MONITOR")
plt.show()
